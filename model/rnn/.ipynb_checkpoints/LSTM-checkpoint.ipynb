# %% [markdown]
# pip install tqdm
# pip install pillow
# pip install image
# pip install keras
# pip install imblearn

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import os
import shutil
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Load data and preprocessing

# %%
train_dataset = pd.read_csv('../../../plant-pathology-2020-fgvc7/train.csv')
test_dataset = pd.read_csv('../../../plant-pathology-2020-fgvc7/test.csv')

# %%
print("-----------------------TRAIN-------------------------- \n :",train_dataset.head())
print("\n Shape : ",train_dataset.shape)
# Out:
# -----------------------TRAIN--------------------------
#  :   image_id  healthy  multiple_diseases  rust  scab
# 0  Train_0        0                  0     0     1
# 1  Train_1        0                  1     0     0
# 2  Train_2        1                  0     0     0
# 3  Train_3        0                  0     1     0
# 4  Train_4        1                  0     0     0
#
#  Shape :  (1821, 5)

# %%
print("-----------------------TEST-------------------------- \n :",test_dataset.head())
print("\n Shape : ",test_dataset.shape)
# Out:
# -----------------------TEST--------------------------
#  :   image_id
# 0   Test_0
# 1   Test_1
# 2   Test_2
# 3   Test_3
# 4   Test_4
#
#  Shape :  (1821, 1)

# %%
train_dataset.describe()
# Out:
#            healthy  multiple_diseases         rust         scab
# count  1821.000000        1821.000000  1821.000000  1821.000000
# mean      0.283361           0.049973     0.341571     0.325096
# std       0.450754           0.217948     0.474367     0.468539
# min       0.000000           0.000000     0.000000     0.000000
# 25%       0.000000           0.000000     0.000000     0.000000
# 50%       0.000000           0.000000     0.000000     0.000000
# 75%       1.000000           0.000000     1.000000     1.000000
# max       1.000000           1.000000     1.000000     1.000000

# %%
targets = train_dataset[['healthy', 'multiple_diseases', 'rust', 'scab']]

# %% [markdown]
#  Split the data into train and validation sets, then take a quick look at their make up.

# %%
train, validation = train_test_split(train_dataset, test_size=0.2)

# %% [markdown]
# Display a picture

# %%
# Retour d'une image de façon aléatoire
randImg = np.random.randint(1820)
img = mpimg.imread(f'../../../plant-pathology-2020-fgvc7/images/Train_{randImg}.jpg')
imgplot = plt.imshow(img)

# %% [markdown]
# On va stocker les images sous formes de données brutes au format LIB

# %%
from tqdm.notebook import tqdm
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array

size = 64

nb_img = train_dataset.shape[0]
path = '../../../plant-pathology-2020-fgvc7/images/'
train_images = np.ndarray(shape=(train_dataset.shape[0], size, size, 3))
test_images = np.ndarray(shape=(test_dataset.shape[0], size, size, 3))

# tqdm pour avoir une barre dévolution
for i in tqdm(range(nb_img)):
  img = load_img(path + f'Train_{i}.jpg', target_size=(size, size))
  train_images[i] = np.float32(img_to_array(img))
    
for i in tqdm(range(nb_img)):
  img = load_img(path + f'Train_{i}.jpg', target_size=(size, size))
  test_images[i] = np.float32(img_to_array(img))
# Out:
# Using TensorFlow backend.
# HBox(children=(FloatProgress(value=0.0, max=1821.0), HTML(value='')))

# %%
print("Train_images :",train_images.shape)
print("Test_images :",test_images.shape)
# Out:
# Train_images : (1821, 64, 64, 3)
# Test_images : (1821, 64, 64, 3)

# %% [markdown]
# Réequilibre des images pour chaque dim

# %%
from imblearn.over_sampling import RandomOverSampler

ros = RandomOverSampler(random_state=42)
x_res, y_res = ros.fit_resample(np.reshape(train_images, (-1, size * size * 3)), targets.to_numpy())
x_res = x_res.reshape((-1, size, size, 3))

# %% [markdown]
# Séparation des données

# %%
x_train, x_test, y_train, y_test = train_test_split(x_res, y_res, test_size=0.2)

# %%
from tensorflow.keras.layers import * # Convolution2D, MaxPooling, Flatten, Dense
from tensorflow.keras.models import * # Sequential
from tensorflow.keras.regularizers import * # 
from tensorflow.keras.optimizers import * #

# %% [markdown]
# Préparation des données avec un ImageDataGenerator

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (1990, 64, 64, 3)
# (1990, 4)
# (498, 64, 64, 3)
# (498, 4)

# %%
train_data = x_train.reshape((x_train.shape[0], size, size*3))
test_data = x_test.reshape((x_test.shape[0], size, size*3))

# %%
train_data.shape
# Out:
# (1990, 64, 192)

# %%
# New train_labels
train_labels = np.ndarray(shape=(train_data.shape[0], 1), dtype=int, order='F')
test_labels = np.ndarray(shape=(test_data.shape[0], 1), dtype=int, order='F')
i = 0
j = 0
while i<train_labels.shape[0]:
    train_labels.put(i,np.argmax(y_train[i]))
    i=i+1
while j<test_labels.shape[0]:
    test_labels.put(j,np.argmax(y_test[j]))
    j=j+1

# %%
train_data = train_data/255
test_data = test_data/255

# %% [markdown]
# ## Modèle Linéaire

# %%
class Linear:

    def __init__(self):
        self.name = "lin"
        self.nb_hidden_layers = 0
        self.layers_size = []
        self.use_layers_activation = False
        self.layers_activation = 'relu'
        self.output_activation = 'softmax'
        self.loss = 'sparse_categorical_crossentropy'
        self.optimizer = 'Adam'
        self.metrics = ['sparse_categorical_accuracy']

# %%
def create_linModel(lin_struct: Linear):
    model = Sequential()
    model.add(Flatten(input_shape=(size, size, 3)))
    model.add(Dense(4, activation=lin_struct.output_activation))
    model.compile(loss=lin_struct.loss,
                  metrics=lin_struct.metrics)

    return model

# %%
#linStruct = Linear()
#linModel = create_linModel(struct)
#print(linModel.summary())

# %%
#linModel.fit(x_train, y_train,epochs=100,batch_size=)

# %%
print(train_data.shape)
print(train_labels.shape)
print(test_data.shape)
print(test_labels.shape)
# Out:
# (1990, 64, 192)
# (1990, 1)
# (498, 64, 192)
# (498, 1)

# %% [markdown]
# ## Modèle RNN (Lstm)

# %% [markdown]
# Structure du LSTM

# %%
class Lstm:

    def __init__(self):
        self.nb_layers = 3
        self.units = 50
        self.activation = 'tanh'
        self.output_activation = 'softmax'
        self.recurrent_activation = 'sigmoid'
        self.dropout_value = 0.0
        self.kernel_regularizer = None
        self.recurrent_regularizer = None
        self.output_regularizer = None
        self.l1_value = 0.001
        self.l2_value = 0.0
        self.loss = 'sparse_categorical_crossentropy'
        self .optimizer = 'Adam'
        self.metrics = ['sparse_categorical_accuracy']

# %%
def create_lstm(lstm_struct: Lstm):

    input_tensor = Input((size, size*3))

    #Ici on va commencer à creer et empiler les différentes couches pour de meilleur prédictions
    lstm_tensor = input_tensor
    for i in range(lstm_struct.nb_layers - 1):
        lstm_tensor = LSTM(units= lstm_struct.units,
                           kernel_regularizer=lstm_struct.kernel_regularizer,
                           recurrent_regularizer=lstm_struct.recurrent_regularizer,
                           dropout=lstm_struct.dropout_value,
                           return_sequences=True
                           )(lstm_tensor)

    #Return_sequences prend False ici 
    lstm_tensor = LSTM(units=lstm_struct.units,
                       kernel_regularizer=lstm_struct.kernel_regularizer,
                       recurrent_regularizer=lstm_struct.recurrent_regularizer,
                       dropout=lstm_struct.dropout_value,
                       return_sequences=False
                       )(lstm_tensor)

    output_tensor = Dense(4, activation=lstm_struct.output_activation, kernel_regularizer=lstm_struct.output_regularizer)(lstm_tensor)

    model = Model(input_tensor, output_tensor)

    model.compile(loss=lstm_struct.loss, optimizer=lstm_struct.optimizer, metrics=lstm_struct.metrics)

    return model

# %%
struct = Lstm()
struct.nb_layers=9
struct.dropout_value = 0.4
struct.l1_value = 0.0
struct.l2_value = 0.0
model = create_lstm(struct)
print(model.summary())
# Out:
# WARNING:tensorflow:Large dropout rate: 0.6 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.6 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.6 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.6 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.6 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 64, 192)]         0
# _________________________________________________________________
# lstm (LSTM)                  (None, 64, 50)            48600
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 64, 50)            20200
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 64, 50)            20200
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 50)                20200
# _________________________________________________________________
# dense (Dense)                (None, 4)                 204
# =================================================================
# Total params: 109,404
# Trainable params: 109,404
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
history = model.fit(train_data, 
          train_labels,
          validation_data=(test_data, test_labels),
          epochs=100,
          batch_size=100)
# Out:
# Train on 1990 samples, validate on 498 samples
# Epoch 1/100
# 1990/1990 [==============================] - 15s 8ms/sample - loss: 1.3824 - sparse_categorical_accuracy: 0.2719 - val_loss: 1.3925 - val_sparse_categorical_accuracy: 0.2490
# Epoch 2/100
# 1990/1990 [==============================] - 1s 405us/sample - loss: 1.3645 - sparse_categorical_accuracy: 0.3045 - val_loss: 1.4051 - val_sparse_categorical_accuracy: 0.2309
# Epoch 3/100
# 1990/1990 [==============================] - 1s 399us/sample - loss: 1.3476 - sparse_categorical_accuracy: 0.3291 - val_loss: 1.3896 - val_sparse_categorical_accuracy: 0.2791
# Epoch 4/100
# 1990/1990 [==============================] - 1s 394us/sample - loss: 1.3325 - sparse_categorical_accuracy: 0.3322 - val_loss: 1.3265 - val_sparse_categorical_accuracy: 0.3735
# Epoch 5/100
# 1990/1990 [==============================] - 1s 394us/sample - loss: 1.3120 - sparse_categorical_accuracy: 0.3578 - val_loss: 1.3055 - val_sparse_categorical_accuracy: 0.3735
# Epoch 6/100
# 1990/1990 [==============================] - 1s 396us/sample - loss: 1.2728 - sparse_categorical_accuracy: 0.3829 - val_loss: 1.2762 - val_sparse_categorical_accuracy: 0.3996
# Epoch 7/100
# 1990/1990 [==============================] - 1s 391us/sample - loss: 1.2960 - sparse_categorical_accuracy: 0.3814 - val_loss: 1.3109 - val_sparse_categorical_accuracy: 0.3594
# Epoch 8/100
# 1990/1990 [==============================] - 1s 393us/sample - loss: 1.2765 - sparse_categorical_accuracy: 0.3809 - val_loss: 1.2602 - val_sparse_categorical_accuracy: 0.4157
# Epoch 9/100
# 1990/1990 [==============================] - 1s 404us/sample - loss: 1.2267 - sparse_categorical_accuracy: 0.4266 - val_loss: 1.2290 - val_sparse_categorical_accuracy: 0.4177
# Epoch 10/100
# 1990/1990 [==============================] - 1s 391us/sample - loss: 1.2292 - sparse_categorical_accuracy: 0.4196 - val_loss: 1.2621 - val_sparse_categorical_accuracy: 0.3574
# Epoch 11/100
# 1990/1990 [==============================] - 1s 396us/sample - loss: 1.2014 - sparse_categorical_accuracy: 0.4357 - val_loss: 1.1745 - val_sparse_categorical_accuracy: 0.4418
# Epoch 12/100
# 1990/1990 [==============================] - 1s 402us/sample - loss: 1.1799 - sparse_categorical_accuracy: 0.4528 - val_loss: 1.1889 - val_sparse_categorical_accuracy: 0.4478
# Epoch 13/100
# 1990/1990 [==============================] - 1s 396us/sample - loss: 1.1390 - sparse_categorical_accuracy: 0.4874 - val_loss: 1.1679 - val_sparse_categorical_accuracy: 0.4598
# Epoch 14/100
# 1990/1990 [==============================] - 1s 398us/sample - loss: 1.1664 - sparse_categorical_accuracy: 0.4749 - val_loss: 1.1804 - val_sparse_categorical_accuracy: 0.4518
# Epoch 15/100
# 1990/1990 [==============================] - 1s 401us/sample - loss: 1.1073 - sparse_categorical_accuracy: 0.4990 - val_loss: 1.1690 - val_sparse_categorical_accuracy: 0.4659
# Epoch 16/100
# 1990/1990 [==============================] - 1s 398us/sample - loss: 1.1022 - sparse_categorical_accuracy: 0.4824 - val_loss: 1.1358 - val_sparse_categorical_accuracy: 0.4900
# Epoch 17/100
# 1990/1990 [==============================] - 1s 402us/sample - loss: 1.0776 - sparse_categorical_accuracy: 0.5035 - val_loss: 1.1621 - val_sparse_categorical_accuracy: 0.4739
# Epoch 18/100
# 1990/1990 [==============================] - 1s 403us/sample - loss: 1.0366 - sparse_categorical_accuracy: 0.5291 - val_loss: 1.0561 - val_sparse_categorical_accuracy: 0.5241
# Epoch 19/100
# 1990/1990 [==============================] - 1s 398us/sample - loss: 1.0585 - sparse_categorical_accuracy: 0.5141 - val_loss: 1.1004 - val_sparse_categorical_accuracy: 0.5080
# Epoch 20/100
# 1990/1990 [==============================] - 1s 392us/sample - loss: 1.0256 - sparse_categorical_accuracy: 0.5307 - val_loss: 1.0763 - val_sparse_categorical_accuracy: 0.5321
# Epoch 21/100
# 1990/1990 [==============================] - 1s 399us/sample - loss: 0.9992 - sparse_categorical_accuracy: 0.5482 - val_loss: 1.0342 - val_sparse_categorical_accuracy: 0.5261
# Epoch 22/100
# 1990/1990 [==============================] - 1s 395us/sample - loss: 0.9733 - sparse_categorical_accuracy: 0.5618 - val_loss: 1.1437 - val_sparse_categorical_accuracy: 0.4920
# Epoch 23/100
# 1990/1990 [==============================] - 1s 400us/sample - loss: 0.9744 - sparse_categorical_accuracy: 0.5603 - val_loss: 1.1073 - val_sparse_categorical_accuracy: 0.5020
# Epoch 24/100
# 1990/1990 [==============================] - 1s 402us/sample - loss: 0.9539 - sparse_categorical_accuracy: 0.5568 - val_loss: 1.0948 - val_sparse_categorical_accuracy: 0.4960
# Epoch 25/100
# 1990/1990 [==============================] - 1s 397us/sample - loss: 0.9838 - sparse_categorical_accuracy: 0.5487 - val_loss: 0.9759 - val_sparse_categorical_accuracy: 0.5622
# Epoch 26/100
# 1990/1990 [==============================] - 1s 399us/sample - loss: 0.9527 - sparse_categorical_accuracy: 0.5623 - val_loss: 1.0884 - val_sparse_categorical_accuracy: 0.4960
# Epoch 27/100
# 1990/1990 [==============================] - 1s 399us/sample - loss: 0.9194 - sparse_categorical_accuracy: 0.5829 - val_loss: 0.9646 - val_sparse_categorical_accuracy: 0.5622
# Epoch 28/100
# 1990/1990 [==============================] - 1s 401us/sample - loss: 0.8758 - sparse_categorical_accuracy: 0.6045 - val_loss: 0.9857 - val_sparse_categorical_accuracy: 0.5663
# Epoch 29/100
# 1990/1990 [==============================] - 1s 397us/sample - loss: 0.9141 - sparse_categorical_accuracy: 0.5698 - val_loss: 1.0218 - val_sparse_categorical_accuracy: 0.5402
# Epoch 30/100
# 1990/1990 [==============================] - 1s 401us/sample - loss: 0.8739 - sparse_categorical_accuracy: 0.6080 - val_loss: 1.0268 - val_sparse_categorical_accuracy: 0.5361
# Epoch 31/100
# 1990/1990 [==============================] - 1s 399us/sample - loss: 0.8599 - sparse_categorical_accuracy: 0.6055 - val_loss: 0.9983 - val_sparse_categorical_accuracy: 0.5562
# Epoch 32/100
# 1990/1990 [==============================] - 1s 394us/sample - loss: 0.8696 - sparse_categorical_accuracy: 0.6055 - val_loss: 0.9631 - val_sparse_categorical_accuracy: 0.5763
# Epoch 33/100
# 1990/1990 [==============================] - 1s 404us/sample - loss: 0.8293 - sparse_categorical_accuracy: 0.6296 - val_loss: 1.0001 - val_sparse_categorical_accuracy: 0.5562
# Epoch 34/100
# 1990/1990 [==============================] - 1s 399us/sample - loss: 0.8391 - sparse_categorical_accuracy: 0.6387 - val_loss: 0.9963 - val_sparse_categorical_accuracy: 0.5442
# Epoch 35/100
# 1990/1990 [==============================] - 1s 400us/sample - loss: 0.8448 - sparse_categorical_accuracy: 0.6176 - val_loss: 1.0065 - val_sparse_categorical_accuracy: 0.5361
# Epoch 36/100
# 1990/1990 [==============================] - 1s 393us/sample - loss: 0.8379 - sparse_categorical_accuracy: 0.6357 - val_loss: 0.9781 - val_sparse_categorical_accuracy: 0.5582
# Epoch 37/100
# 1990/1990 [==============================] - 1s 397us/sample - loss: 0.7931 - sparse_categorical_accuracy: 0.6427 - val_loss: 0.9502 - val_sparse_categorical_accuracy: 0.5703
# Epoch 38/100
# 1990/1990 [==============================] - 1s 401us/sample - loss: 0.7370 - sparse_categorical_accuracy: 0.6814 - val_loss: 1.0198 - val_sparse_categorical_accuracy: 0.5562
# Epoch 39/100
# 1990/1990 [==============================] - 1s 389us/sample - loss: 0.7377 - sparse_categorical_accuracy: 0.6688 - val_loss: 0.9359 - val_sparse_categorical_accuracy: 0.5964
# Epoch 40/100
# 1990/1990 [==============================] - 1s 404us/sample - loss: 0.7422 - sparse_categorical_accuracy: 0.6688 - val_loss: 0.9970 - val_sparse_categorical_accuracy: 0.5582
# Epoch 41/100
# 1990/1990 [==============================] - 1s 399us/sample - loss: 0.7251 - sparse_categorical_accuracy: 0.6854 - val_loss: 0.9993 - val_sparse_categorical_accuracy: 0.5924
# Epoch 42/100
# 1990/1990 [==============================] - 1s 399us/sample - loss: 0.7843 - sparse_categorical_accuracy: 0.6628 - val_loss: 1.0487 - val_sparse_categorical_accuracy: 0.5643
# Epoch 43/100
# 1990/1990 [==============================] - 1s 400us/sample - loss: 0.7312 - sparse_categorical_accuracy: 0.6769 - val_loss: 0.9447 - val_sparse_categorical_accuracy: 0.5803
# Epoch 44/100
# 1990/1990 [==============================] - 1s 394us/sample - loss: 0.6733 - sparse_categorical_accuracy: 0.7050 - val_loss: 0.9831 - val_sparse_categorical_accuracy: 0.5743
# Epoch 45/100
# 1990/1990 [==============================] - 1s 400us/sample - loss: 0.6553 - sparse_categorical_accuracy: 0.7151 - val_loss: 1.1122 - val_sparse_categorical_accuracy: 0.5562
# Epoch 46/100
# 1990/1990 [==============================] - 1s 399us/sample - loss: 0.6617 - sparse_categorical_accuracy: 0.7241 - val_loss: 1.0271 - val_sparse_categorical_accuracy: 0.5803
# Epoch 47/100
# 1990/1990 [==============================] - 1s 396us/sample - loss: 0.6257 - sparse_categorical_accuracy: 0.7357 - val_loss: 0.9462 - val_sparse_categorical_accuracy: 0.5944
# Epoch 48/100
# 1990/1990 [==============================] - 1s 393us/sample - loss: 0.6461 - sparse_categorical_accuracy: 0.7302 - val_loss: 1.1831 - val_sparse_categorical_accuracy: 0.5683
# Epoch 49/100
# 1990/1990 [==============================] - 1s 398us/sample - loss: 0.7042 - sparse_categorical_accuracy: 0.7040 - val_loss: 0.9620 - val_sparse_categorical_accuracy: 0.5904
# Epoch 50/100
# 1990/1990 [==============================] - 1s 392us/sample - loss: 0.6234 - sparse_categorical_accuracy: 0.7312 - val_loss: 0.9822 - val_sparse_categorical_accuracy: 0.6004
# Epoch 51/100
# 1990/1990 [==============================] - 1s 397us/sample - loss: 0.5663 - sparse_categorical_accuracy: 0.7729 - val_loss: 1.0694 - val_sparse_categorical_accuracy: 0.6064
# Epoch 52/100
# 1990/1990 [==============================] - 1s 398us/sample - loss: 0.5871 - sparse_categorical_accuracy: 0.7538 - val_loss: 1.1221 - val_sparse_categorical_accuracy: 0.5863
# Epoch 53/100
# 1990/1990 [==============================] - 1s 396us/sample - loss: 0.6340 - sparse_categorical_accuracy: 0.7352 - val_loss: 1.0403 - val_sparse_categorical_accuracy: 0.5984
# Epoch 54/100
# 1990/1990 [==============================] - 1s 403us/sample - loss: 0.6187 - sparse_categorical_accuracy: 0.7422 - val_loss: 1.0376 - val_sparse_categorical_accuracy: 0.5904
# Epoch 55/100
# 1990/1990 [==============================] - 1s 393us/sample - loss: 0.5545 - sparse_categorical_accuracy: 0.7658 - val_loss: 1.0010 - val_sparse_categorical_accuracy: 0.5984
# Epoch 56/100
# 1990/1990 [==============================] - 1s 393us/sample - loss: 0.5372 - sparse_categorical_accuracy: 0.7749 - val_loss: 1.1119 - val_sparse_categorical_accuracy: 0.6124
# Epoch 57/100
# 1990/1990 [==============================] - 1s 398us/sample - loss: 0.5854 - sparse_categorical_accuracy: 0.7588 - val_loss: 1.0657 - val_sparse_categorical_accuracy: 0.6084
# Epoch 58/100
# 1990/1990 [==============================] - 1s 400us/sample - loss: 0.5795 - sparse_categorical_accuracy: 0.7648 - val_loss: 1.0567 - val_sparse_categorical_accuracy: 0.6024
# Epoch 59/100
# 1990/1990 [==============================] - 1s 398us/sample - loss: 0.5313 - sparse_categorical_accuracy: 0.7809 - val_loss: 1.0642 - val_sparse_categorical_accuracy: 0.5863
# Epoch 60/100
# 1990/1990 [==============================] - 1s 400us/sample - loss: 0.4798 - sparse_categorical_accuracy: 0.8010 - val_loss: 1.0575 - val_sparse_categorical_accuracy: 0.6104
# Epoch 61/100
# 1990/1990 [==============================] - 1s 393us/sample - loss: 0.4862 - sparse_categorical_accuracy: 0.8070 - val_loss: 1.0668 - val_sparse_categorical_accuracy: 0.6124
# Epoch 62/100
# 1990/1990 [==============================] - 1s 397us/sample - loss: 0.5384 - sparse_categorical_accuracy: 0.7814 - val_loss: 1.0652 - val_sparse_categorical_accuracy: 0.5944
# Epoch 63/100
# 1990/1990 [==============================] - 1s 400us/sample - loss: 0.4595 - sparse_categorical_accuracy: 0.8156 - val_loss: 1.1074 - val_sparse_categorical_accuracy: 0.6064
# Epoch 64/100
# 1990/1990 [==============================] - 1s 388us/sample - loss: 0.4797 - sparse_categorical_accuracy: 0.8005 - val_loss: 1.0815 - val_sparse_categorical_accuracy: 0.6064
# Epoch 65/100
# 1990/1990 [==============================] - 1s 403us/sample - loss: 0.4734 - sparse_categorical_accuracy: 0.8211 - val_loss: 1.0612 - val_sparse_categorical_accuracy: 0.6205
# Epoch 66/100
# 1990/1990 [==============================] - 1s 403us/sample - loss: 0.4567 - sparse_categorical_accuracy: 0.8176 - val_loss: 1.1186 - val_sparse_categorical_accuracy: 0.6084
# Epoch 67/100
# 1990/1990 [==============================] - 1s 391us/sample - loss: 0.4712 - sparse_categorical_accuracy: 0.8090 - val_loss: 1.1877 - val_sparse_categorical_accuracy: 0.5904
# Epoch 68/100
# 1990/1990 [==============================] - 1s 399us/sample - loss: 0.4727 - sparse_categorical_accuracy: 0.8065 - val_loss: 1.1714 - val_sparse_categorical_accuracy: 0.5904
# Epoch 69/100
# 1990/1990 [==============================] - 1s 403us/sample - loss: 0.4195 - sparse_categorical_accuracy: 0.8347 - val_loss: 1.1610 - val_sparse_categorical_accuracy: 0.6064
# Epoch 70/100
# 1990/1990 [==============================] - 1s 396us/sample - loss: 0.4052 - sparse_categorical_accuracy: 0.8397 - val_loss: 1.1410 - val_sparse_categorical_accuracy: 0.6104
# Epoch 71/100
# 1990/1990 [==============================] - 1s 399us/sample - loss: 0.3772 - sparse_categorical_accuracy: 0.8563 - val_loss: 1.1066 - val_sparse_categorical_accuracy: 0.6325
# Epoch 72/100
# 1990/1990 [==============================] - 1s 391us/sample - loss: 0.4044 - sparse_categorical_accuracy: 0.8462 - val_loss: 1.1628 - val_sparse_categorical_accuracy: 0.6104
# Epoch 73/100
# 1990/1990 [==============================] - 1s 399us/sample - loss: 0.3709 - sparse_categorical_accuracy: 0.8688 - val_loss: 1.1856 - val_sparse_categorical_accuracy: 0.6145
# Epoch 74/100
# 1990/1990 [==============================] - 1s 396us/sample - loss: 0.3897 - sparse_categorical_accuracy: 0.8583 - val_loss: 1.2559 - val_sparse_categorical_accuracy: 0.5964
# Epoch 75/100
# 1990/1990 [==============================] - 1s 400us/sample - loss: 0.3819 - sparse_categorical_accuracy: 0.8523 - val_loss: 1.1577 - val_sparse_categorical_accuracy: 0.6406
# Epoch 76/100
# 1990/1990 [==============================] - 1s 398us/sample - loss: 0.3394 - sparse_categorical_accuracy: 0.8698 - val_loss: 1.2601 - val_sparse_categorical_accuracy: 0.6124
# Epoch 77/100
# 1990/1990 [==============================] - 1s 404us/sample - loss: 0.3536 - sparse_categorical_accuracy: 0.8618 - val_loss: 1.3150 - val_sparse_categorical_accuracy: 0.6265
# Epoch 78/100
# 1990/1990 [==============================] - 1s 400us/sample - loss: 0.3763 - sparse_categorical_accuracy: 0.8513 - val_loss: 1.1846 - val_sparse_categorical_accuracy: 0.6104
# Epoch 79/100
# 1990/1990 [==============================] - 1s 396us/sample - loss: 0.3481 - sparse_categorical_accuracy: 0.8749 - val_loss: 1.1908 - val_sparse_categorical_accuracy: 0.6365
# Epoch 80/100
# 1990/1990 [==============================] - 1s 401us/sample - loss: 0.3360 - sparse_categorical_accuracy: 0.8714 - val_loss: 1.2343 - val_sparse_categorical_accuracy: 0.6104
# Epoch 81/100
# 1990/1990 [==============================] - 1s 392us/sample - loss: 0.3488 - sparse_categorical_accuracy: 0.8729 - val_loss: 1.2486 - val_sparse_categorical_accuracy: 0.6265
# Epoch 82/100
# 1990/1990 [==============================] - 1s 391us/sample - loss: 0.3044 - sparse_categorical_accuracy: 0.8854 - val_loss: 1.2348 - val_sparse_categorical_accuracy: 0.6044
# Epoch 83/100
# 1990/1990 [==============================] - 1s 395us/sample - loss: 0.3470 - sparse_categorical_accuracy: 0.8668 - val_loss: 1.2696 - val_sparse_categorical_accuracy: 0.6104
# Epoch 84/100
# 1990/1990 [==============================] - 1s 397us/sample - loss: 0.3415 - sparse_categorical_accuracy: 0.8598 - val_loss: 1.1550 - val_sparse_categorical_accuracy: 0.6446
# Epoch 85/100
# 1990/1990 [==============================] - 1s 396us/sample - loss: 0.3053 - sparse_categorical_accuracy: 0.8879 - val_loss: 1.2715 - val_sparse_categorical_accuracy: 0.6265
# Epoch 86/100
# 1990/1990 [==============================] - 1s 402us/sample - loss: 0.3014 - sparse_categorical_accuracy: 0.8809 - val_loss: 1.3136 - val_sparse_categorical_accuracy: 0.6044
# Epoch 87/100
# 1990/1990 [==============================] - 1s 396us/sample - loss: 0.3287 - sparse_categorical_accuracy: 0.8754 - val_loss: 1.2648 - val_sparse_categorical_accuracy: 0.6265
# Epoch 88/100
# 1990/1990 [==============================] - 1s 399us/sample - loss: 0.2852 - sparse_categorical_accuracy: 0.8970 - val_loss: 1.2274 - val_sparse_categorical_accuracy: 0.6285
# Epoch 89/100
# 1990/1990 [==============================] - 1s 398us/sample - loss: 0.3178 - sparse_categorical_accuracy: 0.8819 - val_loss: 1.2671 - val_sparse_categorical_accuracy: 0.6165
# Epoch 90/100
# 1990/1990 [==============================] - 1s 400us/sample - loss: 0.2956 - sparse_categorical_accuracy: 0.8864 - val_loss: 1.3320 - val_sparse_categorical_accuracy: 0.6185
# Epoch 91/100
# 1990/1990 [==============================] - 1s 393us/sample - loss: 0.2880 - sparse_categorical_accuracy: 0.8935 - val_loss: 1.2777 - val_sparse_categorical_accuracy: 0.6205
# Epoch 92/100
# 1990/1990 [==============================] - 1s 394us/sample - loss: 0.2379 - sparse_categorical_accuracy: 0.9090 - val_loss: 1.4335 - val_sparse_categorical_accuracy: 0.6024
# Epoch 93/100
# 1990/1990 [==============================] - 1s 401us/sample - loss: 0.2365 - sparse_categorical_accuracy: 0.9176 - val_loss: 1.4391 - val_sparse_categorical_accuracy: 0.6165
# Epoch 94/100
# 1990/1990 [==============================] - 1s 395us/sample - loss: 0.2687 - sparse_categorical_accuracy: 0.8970 - val_loss: 1.3758 - val_sparse_categorical_accuracy: 0.6145
# Epoch 95/100
# 1990/1990 [==============================] - 1s 394us/sample - loss: 0.2636 - sparse_categorical_accuracy: 0.9015 - val_loss: 1.3767 - val_sparse_categorical_accuracy: 0.6305
# Epoch 96/100
# 1990/1990 [==============================] - 1s 392us/sample - loss: 0.2250 - sparse_categorical_accuracy: 0.9196 - val_loss: 1.4027 - val_sparse_categorical_accuracy: 0.6345
# Epoch 97/100
# 1990/1990 [==============================] - 1s 396us/sample - loss: 0.2360 - sparse_categorical_accuracy: 0.9090 - val_loss: 1.4644 - val_sparse_categorical_accuracy: 0.6145
# Epoch 98/100
# 1990/1990 [==============================] - 1s 400us/sample - loss: 0.2428 - sparse_categorical_accuracy: 0.9101 - val_loss: 1.4614 - val_sparse_categorical_accuracy: 0.6044
# Epoch 99/100
# 1990/1990 [==============================] - 1s 398us/sample - loss: 0.2544 - sparse_categorical_accuracy: 0.9025 - val_loss: 1.4201 - val_sparse_categorical_accuracy: 0.5944
# Epoch 100/100
# 1990/1990 [==============================] - 1s 397us/sample - loss: 0.2952 - sparse_categorical_accuracy: 0.8925 - val_loss: 1.2548 - val_sparse_categorical_accuracy: 0.6064

# %%
plt.plot(history.history['sparse_categorical_accuracy'], label='sparse_categorical_accuracy')
plt.plot(history.history['val_sparse_categorical_accuracy'], label='val_sparse_categorical_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.3, 1])
plt.legend(loc='lower right')

# %%
from keras_preprocessing.image import ImageDataGenerator
train_datagen = ImageDataGenerator(rescale = 1./255,
	    rotation_range=40,
      zoom_range=0.2,
      width_shift_range=0.2,
      height_shift_range=0.2,
      horizontal_flip=True,
      vertical_flip=True,
      fill_mode='nearest')

validation_datagen = ImageDataGenerator(rescale = 1./255)

train_generator = train_datagen.flow(
    x = x_train, 
    y = y_train,
    batch_size = 32
    )

validation_generator = validation_datagen.flow(
    x = x_test,
    y = y_test,
    batch_size = 32
    )

# %% [markdown]
# ## Modèle CNN

# %% [markdown]
# Premier test avec un model qui contient deux couches de conv(32,64) et Sorti(128) ==> accuracy: 0.2432 - val_accuracy: 0.2771
#
# Deuxieme test avec un model qui contient trois couches de convolution (32,64,128) et Sorti(128-256) ==> accuracy: 0.2482 - val_accuracy: 0.2570
#
# Troisième test avec un model qui contient quatres couches de convolution (32,64,128,256) et Sorti(128-256) ==>
#
# Quatrième test avec un model qui contient cinqs couches de convolution (32,64,128,256,512) et Sorti(128-256) ==>

# %%
"""
def create_cnn():
    model = Sequential()
    model.add(Conv2D(32, (3,3), input_shape=(size, size, 3), activation='relu')),
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(3,3), strides=(2,2))),
    model.add(Dropout(0.4)),
    
    model.add(Conv2D(64, (3,3), activation='relu')),
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(3,3), strides=(2,2))),
    model.add(Dropout(0.4)),
    
    model.add(Conv2D(128, (3,3), activation='relu')),
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(3,3), strides=(2,2))),
    model.add(Dropout(0.4)),
    
    model.add(Conv2D(256, (3,3), activation='relu')),
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(3,3), strides=(2,2))),
    model.add(Dropout(0.6)),
    
    model.add(Flatten()),
    model.add(Dropout(0.4)),
    
    model.add(Dense(256, activation='relu')),
    model.add(Dense(4, activation='softmax'))
    
    model.compile(loss = 'kullback_leibler_divergence', 
        optimizer = 'Adam', 
        metrics = ['accuracy'])
    
    return model
    
"""
# Out:
# "\ndef create_cnn():\n    model = Sequential()\n    model.add(Conv2D(32, (3,3), input_shape=(size, size, 3), activation='relu')),\n    model.add(BatchNormalization())\n    model.add(MaxPooling2D(pool_size=(3,3), strides=(2,2))),\n    model.add(Dropout(0.4)),\n    \n    model.add(Conv2D(64, (3,3), activation='relu')),\n    model.add(BatchNormalization())\n    model.add(MaxPooling2D(pool_size=(3,3), strides=(2,2))),\n    model.add(Dropout(0.4)),\n    \n    model.add(Conv2D(128, (3,3), activation='relu')),\n    model.add(BatchNormalization())\n    model.add(MaxPooling2D(pool_size=(3,3), strides=(2,2))),\n    model.add(Dropout(0.4)),\n    \n    model.add(Conv2D(256, (3,3), activation='relu')),\n    model.add(BatchNormalization())\n    model.add(MaxPooling2D(pool_size=(3,3), strides=(2,2))),\n    model.add(Dropout(0.6)),\n    \n    model.add(Flatten()),\n    model.add(Dropout(0.4)),\n    \n    model.add(Dense(256, activation='relu')),\n    model.add(Dense(4, activation='softmax'))\n    \n    model.compile(loss = 'kullback_leibler_divergence', \n        optimizer = 'Adam', \n        metrics = ['accuracy'])\n    \n    return model\n    \n"

# %%
"""
model_cnn = create_cnn()
model_cnn.fit(x_train, 
          y_train,
          validation_data=(x_test, y_test),
          epochs=100,
          batch_size=400)
          
"""
# Out:
# '\nmodel_cnn = create_cnn()\nmodel_cnn.fit(x_train, \n          y_train,\n          validation_data=(x_test, y_test),\n          epochs=100,\n          batch_size=400)\n          \n'

# %% [markdown]
# ## Fonction de test de model
